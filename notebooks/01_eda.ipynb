# %% [markdown]
# # 01 - Exploratory Data Analysis
#
# Investigates descriptive statistics, missing values and visual patterns for flight delays.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT / 'src'))

# %%
from flight_delays.data import basic_eda_tables, load_flights
from flight_delays.reporting import plot_eda_figures

flights = load_flights(nrows=100_000)
flights.shape

# %%
flights.head()

# %%
flights.describe(include='all').T.head(30)

# %%
tables = basic_eda_tables(flights)
tables['missing_values'].head(20)

# %%
tables['airline_delay_profile'].head(15)

# %%
tables['origin_airport_delay_profile'].head(15)

# %%
tables['scheduled_hour_delay_profile']

# %%
plot_eda_figures(flights)

# %% [markdown]
# ## Initial Interpretation
#
# Use this section to record which airlines, airports and hours concentrate higher delay rates. Confirm conclusions with the full dataset before the final video.
