# %% [markdown]
# # 02 - Supervised Classification
#
# Predicts whether a flight will arrive more than 15 minutes late.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT / 'src'))

# %%
from flight_delays.data import load_flights
from flight_delays.features import build_model_frame, feature_lists
from flight_delays.modeling import evaluate_classification

flights = load_flights(nrows=100_000)
model_frame = build_model_frame(flights)
model_frame.head()

# %%
numeric_features, categorical_features = feature_lists(model_frame)
numeric_features, categorical_features

# %%
classification_results = evaluate_classification(flights)
classification_results.metrics

# %%
classification_results.predictions.head()

# %% [markdown]
# ## Interpretation Checklist
#
# - Compare F1 and ROC-AUC across the two algorithms.
# - Check whether recall is enough for the business goal.
# - Explain that only pre-flight features were used to avoid leakage.
