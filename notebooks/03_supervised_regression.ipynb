# %% [markdown]
# # 03 - Supervised Regression
#
# Predicts the arrival delay duration in minutes for completed flights.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT / 'src'))

# %%
from flight_delays.data import load_flights
from flight_delays.modeling import evaluate_regression

flights = load_flights(nrows=100_000)
regression_results = evaluate_regression(flights)
regression_results.metrics

# %%
regression_results.predictions.head()

# %%
regression_results.predictions.describe().T

# %% [markdown]
# ## Interpretation Checklist
#
# - Prefer MAE for business readability because it is measured in minutes.
# - Use RMSE to discuss large-error sensitivity.
# - Mention that extreme weather and operational disruptions are hard to predict from schedule-only features.
